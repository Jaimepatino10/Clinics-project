# %% [markdown]
# # Clinics Transformed

# %%
import pandas as pd

# Enlace de descarga directa de OneDrive
url = "https://fhcsn-my.sharepoint.com/:x:/g/personal/laura_soto_sehma_com/EaRgiCbsKlVPrZRCypcbCdUBLkaWJOd76kapNp36lH1tUQ?email=Jaime.Patino%40sehma.com&e=XFBSEQ"

# Leer la tabla
df = pd.read_excel(url)

# Mostrar las primeras filas
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[1], line 7
#       4 url = "https://fhcsn-my.sharepoint.com/:x:/g/personal/laura_soto_sehma_com/EaRgiCbsKlVPrZRCypcbCdUBLkaWJOd76kapNp36lH1tUQ?email=Jaime.Patino%40sehma.com&e=XFBSEQ"
#       6 # Leer la tabla
# ----> 7 df = pd.read_excel(url)
#       9 # Mostrar las primeras filas
#      10 print(df.head())
#
# File c:\Users\Jaime.Patino\OneDrive - South Eastern Health Care Managment\documents\Clinics reports department\environment\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
# ...
